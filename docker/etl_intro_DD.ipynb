# %% [markdown]
# # Objectives

# %% [markdown]
# - What does **ETL** stands for ? What are the use cases ? i.e. What are possible scenarios for each step E, T and L ?
# - What is the difference between **OLAP and OLTP** ?
# - Example: ETL step in the project

# %% [markdown]
# # Warm-up

# %% [markdown]
# **Split into two groups:**
#
# Group 1: Discuss how a website uses a database
#
# Group 2: Discuss how a data analyst uses a database
#
# Think about the type of queries, speed of queries, amount of queries and amount of data

# %% [markdown]
# ### A:

# %% [markdown]
# ### What is the difference between OLAP and OLTP ?

# %% [markdown]
# ![etl.png](attachment:etl.png)

# %% [markdown]
# ## 1. What does ETL stands for ? What are the use cases ?

# %% [markdown]
# ![ETL-100.jpeg](attachment:ETL-100.jpeg)

# %% [markdown]
# ## 2. Example: ETL step in the project
