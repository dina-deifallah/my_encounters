# %% [markdown]
# # Objectives

# %% [markdown]
# 1. What is docker-compose ?
# 2. Example: Karaokebot: building a pipeline of python + postgres db
# 3. Overview of this week's data pipeline

# %% [markdown]
# # Warm-up

# %% [markdown]
# **Postgres inside Docker Challenge - 15 mins - work in groups of 2-3 people**
#
# [instructions here](https://krspiced.pythonanywhere.com/chapters/project_pipeline/docker/README.html)

# %% [markdown]
# ### A:

# %% [markdown]
# *docker run -d --name mypg -p 5555:5432 -e POSTGRES_PASSWORD=xxxx postgres*
#
#
# **Connect from your own computer**
#
#
# MAC/LINUX:
# *psql -h 127.0.0.1 -p 5555 -U postgres*
#
# WINDOWS:
# *psql -h 192.168.99.100 -p 5555 -U postgres*
#
# **Next, connect from inside Docker**
#
#
# *docker exec -it mypg psql -p 5432 -U postgres*

# %% [markdown]
# ## 1. docker-compose

# %% [markdown]
# ### 1.1 What is a docker pipeline ?

# %% [markdown]
# ![Screenshot%202021-11-02%20at%2012.40.39.png](attachment:Screenshot%202021-11-02%20at%2012.40.39.png)

# %% [markdown]
# ### 1.2 How does it work ?

# %% [markdown]
# - Docker compose starts with a file, a yml, where you define what your pipeline or architecture consists for, with the smallest unit being a container
#
# - We need to think about 3 things:
# 1. ports
# 2. environment variables
# 3. shared volumes
#
#
# - Docker compose file has paragraphs, each of which defines a container. The indentation is important.
# - yml: yet another markup language

# %% [markdown]
# ## 2. Example: Karaokebot: building a pipeline of python + postgres db

# %% [markdown]
# ## 3. Overview of this week's data pipeline

# %% [markdown]
# ![docker_pipeline.png](attachment:docker_pipeline.png)
